# %%
            "--------------GIT KOMUTLARI-------------"
# Bu linkte Türkce olarak temel seviye de nasil push ve sonrasinda güncelleme yapilmak isteniyorsa anlatiliyor. https://www.youtube.com/watch?v=-tq5V07UXXc
# git-school.github.io
" git open source distributed version control system
# Github cloud gibi düsünülebilir.
" origin remaut da ki reponun default adi.
" Tocen almak icin Settings/Developerssettings/Personal access tokens/ new Tocen
# git config --global user.name “Your Name” /Kullanici adini degistirme komutu
" git config --global user.email “you@example.com” / Kullanici mail degistirme.
# git config --global color.ui auto
" git config --list =genel kullanici bilgilerine ulasmak icin.
" git branch : tüm branchlarin adini gösterir.
# git branch -r : Bize Remot'u verir. Remote de kimlerin oldugunu. Ahmet/Pakize/Ferhat.
" git branch -a : Tüm branchlari ve Remoteleri veririr. dev1, main  / ferhat/enes/oguzhan
# git branch xxxx : Yeni branch olusturmak icin
" git branch -d xxxxx : Bir branch silmek icin
# git branch -D xxxxx : Bir branch'i kalici olarak silmek icin.
" git checkout hash kodu veya o committin adi : o commit'e gecmek icin.
# Head pozisyonu : O an üzerinde calisilan konum.
" git init = gizli dosya olusturma
# git remote add origin https ... : github da ki repo ile pc de ki repoyu iliskilendirme. 
" git clone [project url] = Uzak depodan tüm geçmişi olan bir proje indirir.
# git clone https://token@remote copy linkinin devami.
# git status = Çalışma dizininizin durumunu görüntüler. Seçenekler arasında yeni, aşamalı ve değiştirilmiş dosyalar
" git add xxxx = Add a file to the staging area
# git add . = Sonda ki noktadan dolayi hepsini Untracked files dan committed'e tasiyor.
" git diff main origin/main : main ile remot da ki origin/main arasinda ki farki gösterir.
# 1. git add xxxx
# 2. git commit -m "asd"
# 3. git push -u origin main

# git push https://token@copy linkinin devami.
# git diff --staged = Shows any changes between the staging area and the repository.
" git -restore xxx : Stage de bulunan dosyayi Working Direckterye geri aliyor.
# git checkout -a1.txt = Çalışma dizinindeki değişiklikleri atın. Bu işlem kurtarılamaz. Commit id si verildiginde o an ki haline geri döner.
" git reset = Stage areaya gönderdigimiz doslari working direckterye geri getirir. Deponuzu bilinen önceki bir çalışma durumuna döndürün.
# git rm xxx = Dosyayı çalışma dizininden ve hazırlama alanından silin.
" git stash = Çalışma dizininizdeki mevcut değişiklikleri daha sonra kullanmak üzere zulaya koyun.
# git stash pop = Depolanan zula içeriğini çalışma dizinine uygulayın ve zulayı temizleyin.
" git stash drop = Önceki tüm zulalarınızdan belirli bir zulayı silin.
# git log = Repoda olanlari gösteriyor. Yapilan tüm commitleri gösteriyor. Dosyalarin tarihcelerini ögrenebiliriz. Kim ne yapmis? Ve burada dosyalarin ilgili numarasini bulup onlari geri cagirabiliyoruz.
" git log -p = Bu komut, tüm dosyalar ve değişiklikleri dahil olmak üzere taahhüdün geçmişini gösterir.
# git log --oneline : yapilan commitlerin aciklamalarini gösteriyor.
" git log --pretty : yapilan commitleri ve id'leri gösteriyor.
" git reflog = Yerel depoda yapılan işlemleri (ör. checkouts or commits) listeleyin.
# git tag = list all tags
" git tag -a dosya adi -m "Buraya bir not yazmak gerekiyor" = Bu sekilde etiketler olusturabiliyoruz.
# git tag -d <tag-adi> = Kayitli taglerden birini silmek icin.
" ana branch’e merge olduktan sonra branch’in hayatı sona erer. Branch’ler sürekli eklenip silinirler.Etiketler ise sonsuza kadar kalma eğilimindedir."
" branch’ler dinamik, etiketler ise sabittir.
# git checkout -b <branch adi> = Hem branch olusturma hem de o branch'a checkout yapma.
" git revert [comitt'in hash kodu] = Belirtilen taahhütteki değişiklikleri geri alarak yeni bir taahhüt oluşturun. Değişikliklerin tersine çevrilmesini sağlar.
# git fetch [remote] = Remoteden değişiklikleri alın, ancak izleme dallarını güncellemeyin. Sonrasinda merge gerekir.
" git merge ve branch adi : Suanda hangi branch da isek merge den sonra yazilan branch suanda oldugumuz branch'a merge edilir.
# git merge dev1 dev1 : ayni anda 2 merge yapmak mümkündür.
" Fast forward merge : Master branch'indan bir tane yeni branch (feature-1)olusturduk ve daha sonra bu ikisini merge edersek bun fast forward merge denir.
"Yani ana branch da degisiklik yok. Dallandirdigimiz branch'da degisiklik var.
# git pull [remote] = fetch ve merge'in birlestirilmis halidir. Cloneden farki; bir repositoryi ilk defa PC'ye indireceksek clone etmemiz lazim.
# bir ay sonra bu dosyaya baskalari yeni bir seyler ekledilerse ve bunlari almak istiyorsak pull.
" git push [--tags] [remote] = Yerel değişiklikleri Remoteye aktarın. Etiketleri itmek için --tags kullanın.
" git push -u origin [branch] = Push local branch to remote repository. Bir kez yapildiktan sonra sonrakiler icin sadece git push yeterli.
# git commit -m "Icine msj yazilmasi gerekiyor." = Dosyalari Repoya tasiyoruz.
" git commit --amend = Git de ki en son commit'i degistirme.
# git commit --amend -m "basj üzerinden ilk komut degistirildi."
" git checkout hash kodu : gecmis yorumlar üzerinde degisiklik yapmak icin.
# git commit -am "mesaj" = Stage'e atmadan (add) hepsi tek seferde Repoya eklenebilir ve kaydedilebilir.
" Git, kaynak kod geçmişinizi yerel olarak yönetmenize ve takip etmenize izin veren bir sürüm kontrol sistemidir.
" GitHub, Git depolarını yönetmenize izin veren bulut tabanlı bir barındırma hizmetidir.
# git remote add origin https.... = Bu komut GitHub'a yerel git deposu ekler.
# git remote -v : Tanimli originleri gösteriyor. 
" git add fil* = fil ile baslayip sonu egal hepsini to staging area in Git.
# git log --stat = Bu komut, Git günlüğünün, değiştirilen satır(lar) ve dosya adları dahil olmak üzere her bir taahhütteki değişikliklerle ilgili bazı istatistikleri göstermesine neden olur.
" git rm dosya adi = working direckterydekini kaldirir.
# git mv oldfile newfile = Dosya adi degistirme.
" git reset HEAD filename = Yapilan degisikleri geri almak icin kullanilan bir komut.
# git reset HEAD -p =               "
" pull request (Cekme istegi): Yaptigimiz degisiklikleri master'a merge etmek icin Senior developper'a istekde bulunuyoruz. Pull request bu istegin adi.
# fork : catallama (github sayfasina girdikten sonra sag üstte.) Baskasinin Githubindan remotiyi kendi repomuzun altina catal yapma.
# Catallama yapinca bizim repositorimize ekleniyor.
" GITHUB'DA HOCANIN REPOSUNDA BENIM ADIMA ACILAN BRANCH'A PUSH YAPMAK ICIN ILK OLARAK O BRANCH'A CHECKOUT YAPIYORUZ. Sonra ki islemler normal devam ediyor.
# Git push origin HEAD:ferhat : Bu komut ile en son github'a gönderdigim file'in branch'ini degistiriyorum ve ferhat branch'ina aliyorum.
" Benim branchimin altinda ki bir dosyayi main'e tasimak icin pull request yapmak gerekiyor. Benim branch sayfamda bunun butonu var. Sonrasinda main branch ile merge olmus oluyor.
# git branch -m ferhat dursun : ferhat branch'in halihazirda ki adi.
".gitignore : yerelde bir dosyanin icerisine olustulduktan sonra bunun icerisine yazilan klasör, dosya adilari veya file ad veya uzantilari github'a gönderilmez.
" .gitignore kriterlerini degistirmek icin icerisine girip istenilen dosyalarin adi veya uzantilarinin silinmesi gerekmektedir.
# git resert --hard ve hash kodu : Bulundugumuz noktadan bu hash koduna kadar olan commitleri siliyor.
" git rebase dev1 ---> Suanda master branch'indayiz. HEAD master'da. bu komut master branch'inin olusturuldugu yerden sonuna kadar olan commitleri aliyor dev1'in sonuna ekliyor.
# git config --global alias.fd"status" : alias tanimlama. fd'ye kadar hepsi ayni kalip (nokta dahil).
# alias degistirmek istersek tüm kodu aynen yaziyoruz sadece alias olarak tanimladigimiz fd icin baska bir alias yazip enter yapiyoruz.
" git config --global --edit --> aliaslar, kullanici adi ve maili ile ilgili bilgileri veriyor. Ve bu acialan nano veya vim ekranindan direkt olarak degisiklik yapabiliyoruz.
# git fd"alias ile commit edilmistir." (Burada ki fd commit ile yerine yazilmis olan alias)
# cat merhaba > test3.txt : cat burada merhaba adinda ki klasörü oder file test3.txt adinda bir klasör veya bir file olusturarak icerisine kopyaliyor.
" cat > merhaba : bu sekilde enter yaptiktan sonra terminal de bir alt satira gecip bu file in icerisine istedigimizi yazabiliriz ancak üstüne yaziyor.
# git config --list : git ile alakali genel bilgiler veriyor .
" git diff main origin/main : main ile remot da ki origin/main arasinda ki farki gösteriyor.
